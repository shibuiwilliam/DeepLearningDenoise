# %% [markdown]
# # Convolutional AutoEncoder for denoising Cifar dataset

# %% [markdown]
# ## Backend and Import

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
kerasBKED = os.environ["KERAS_BACKEND"] 
print(kerasBKED)
# Out:
# tensorflow

# %%
import keras
from keras.models import load_model
from keras.datasets import cifar10
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, Activation
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
import os
import pickle
import numpy as np
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load Cifar10 dataset

# %%
batch_size = 32
num_classes = 10
epochs = 100
saveDir = "/opt/files/python/transfer/ae/"
if not os.path.isdir(saveDir):
    os.makedirs(saveDir)

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train_line = np.copy(x_train)
x_test_line = np.copy(x_test)

# %% [markdown]
# ## draw lines to data

# %%
def drawLines(x):
    for i in range(len(x)):
        numLines = np.random.randint(20) + 1
        for l in range(numLines):
            if l % 2 == 0:
                vh = np.random.randint(2)
                start = np.random.randint(10)
                length = start + np.random.randint(4,21)
                position = np.random.randint(32)
                for j in range(3):
                    if vh == 0:
                        x[i,:,:,j][start:length, position] = 0
                    else:
                        x[i,:,:,j][position, start:length] = 0
            else:
                vh = np.random.randint(2)
                start = np.random.randint(10,25)
                length = start + np.random.randint(5,32-start)
                position = np.random.randint(32)
                for j in range(3):
                    if vh == 0:
                        x[i,:,:,j][start:length, position] = 0
                    else:
                        x[i,:,:,j][position, start:length] = 0
    return x

# %%
x_train_line = drawLines(x_train_line)
x_test_line = drawLines(x_test_line)

# %% [markdown]
# ## normalize data

# %%
# normalize data
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# normalize data
x_train_line = x_train_line.astype('float32')
x_test_line = x_test_line.astype('float32')
x_train_line /= 255
x_test_line /= 255

# %%
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## show noisy images

# %%
# definition to show original image and reconstructed image
def showOrigDec(orig, noise, num=10):
    import matplotlib.pyplot as plt
    n = num
    plt.figure(figsize=(20, 4))

    for i in range(n):
        # display original
        ax = plt.subplot(2, n, i+1)
        plt.imshow(orig[i].reshape(32, 32, 3))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        
        # display noisy
        ax = plt.subplot(2, n, i +1 + n)
        plt.imshow(noise[i].reshape(32, 32, 3))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
showOrigDec(x_train, x_train_line)

# %%
showOrigDec(x_train[100:], x_train_line[100:])

# %%
showOrigDec(x_train[200:], x_train_line[200:])

# %% [markdown]
# ## Convolutional AutoEncoder for denoising

# %%
input_img = Input(shape=(32, 32, 3))
x = Conv2D(32, (3, 3), padding='same')(input_img)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

x = Conv2D(32, (3, 3), padding='same')(encoded)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(3, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
decoded = Activation('sigmoid')(x)

# %%
model = Model(input_img, decoded)
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# ## Train AutoEncoder

# %%
# load pretrained weights
# model.load_weights(saveDir + "AutoEncoder_Cifar10_deline_weights.05-0.55-0.55.hdf5")

# %%
es_cb = EarlyStopping(monitor='val_loss', patience=2, verbose=1, mode='auto')
chkpt = saveDir + 'AutoEncoder_Cifar10_deline_weights.{epoch:02d}-{loss:.2f}-{val_loss:.2f}.hdf5'
cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

# %%
history = model.fit(x_train_line, x_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test_line, x_test),
                    callbacks=[es_cb, cp_cb],
                    shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 49888/50000 [============================>.] - ETA: 0s - loss: 0.0030Epoch 00000: val_loss improved from inf to 0.00309, saving model to /opt/files/python/transfer/ae/AutoEncoder_Cifar10_deline_weights.00-0.00-0.00.hdf5
# 50000/50000 [==============================] - 26s - loss: 0.0030 - val_loss: 0.0031
# Epoch 2/100
# 49888/50000 [============================>.] - ETA: 0s - loss: 0.0029Epoch 00001: val_loss improved from 0.00309 to 0.00260, saving model to /opt/files/python/transfer/ae/AutoEncoder_Cifar10_deline_weights.01-0.00-0.00.hdf5
# 50000/50000 [==============================] - 26s - loss: 0.0029 - val_loss: 0.0026
# Epoch 3/100
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.0029Epoch 00002: val_loss did not improve
# 50000/50000 [==============================] - 26s - loss: 0.0029 - val_loss: 0.0029
# Epoch 4/100
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.0029Epoch 00003: val_loss improved from 0.00260 to 0.00255, saving model to /opt/files/python/transfer/ae/AutoEncoder_Cifar10_deline_weights.03-0.00-0.00.hdf5
# 50000/50000 [==============================] - 26s - loss: 0.0029 - val_loss: 0.0025
# Epoch 5/100
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.0028Epoch 00004: val_loss did not improve
# 50000/50000 [==============================] - 26s - loss: 0.0028 - val_loss: 0.0027
# Epoch 6/100
# 49952/50000 [============================>.] - ETA: 0s - loss: 0.0028Epoch 00005: val_loss did not improve
# 50000/50000 [==============================] - 26s - loss: 0.0028 - val_loss: 0.0026
# Epoch 7/100
# 49952/50000 [============================>.] - ETA: 0s - loss: 0.0028Epoch 00006: val_loss improved from 0.00255 to 0.00252, saving model to /opt/files/python/transfer/ae/AutoEncoder_Cifar10_deline_weights.06-0.00-0.00.hdf5
# 50000/50000 [==============================] - 26s - loss: 0.0028 - val_loss: 0.0025
# Epoch 8/100
# 49888/50000 [============================>.] - ETA: 0s - loss: 0.0028Epoch 00007: val_loss improved from 0.00252 to 0.00249, saving model to /opt/files/python/transfer/ae/AutoEncoder_Cifar10_deline_weights.07-0.00-0.00.hdf5
# 50000/50000 [==============================] - 26s - loss: 0.0028 - val_loss: 0.0025
# Epoch 9/100
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.0028Epoch 00008: val_loss did not improve
# 50000/50000 [==============================] - 26s - loss: 0.0028 - val_loss: 0.0027
# Epoch 10/100
# 49952/50000 [============================>.] - ETA: 0s - loss: 0.0028Epoch 00009: val_loss did not improve
# 50000/50000 [==============================] - 26s - loss: 0.0028 - val_loss: 0.0027
# Epoch 11/100
# 49952/50000 [============================>.] - ETA: 0s - loss: 0.0027Epoch 00010: val_loss did not improve
# 50000/50000 [==============================] - 26s - loss: 0.0027 - val_loss: 0.0025
# Epoch 00010: early stopping

# %% [markdown]
# ## Evaluate with test dataset

# %%
score = model.evaluate(x_test_line, x_test, verbose=1)
print(score)
# Out:
# 10000/10000 [==============================] - 1s
# 0.00251344182827

# %% [markdown]
# ## Visualize original image, noisy image and denoised image

# %%
c10test = model.predict(x_test_line)

# %%
print("Cifar10_test: {0}".format(np.average(c10test)))
# Out:
# Cifar10_test: 0.483312726020813

# %%
# definition to show original image and reconstructed image
def showOrigDec(orig, noise, denoise, num=10):
    import matplotlib.pyplot as plt
    n = num
    plt.figure(figsize=(20, 6))

    for i in range(n):
        # display original
        ax = plt.subplot(3, n, i+1)
        plt.imshow(orig[i].reshape(32, 32, 3))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # display noisy image
        ax = plt.subplot(3, n, i +1 + n)
        plt.imshow(noise[i].reshape(32, 32, 3))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        
        # display denoised image
        ax = plt.subplot(3, n, i +1 + n + n)
        plt.imshow(denoise[i].reshape(32, 32, 3))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
showOrigDec(x_test, x_test_line, c10test)

# %%
showOrigDec(x_test[100:], x_test_line[100:], c10test[100:])

# %%
showOrigDec(x_test[200:], x_test_line[200:], c10test[200:])
