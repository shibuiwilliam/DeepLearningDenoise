# %% [markdown]
# # Convolutional AutoEncoder for denoising Cifar dataset

# %% [markdown]
# ## Backend and Import

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
kerasBKED = os.environ["KERAS_BACKEND"] 
print(kerasBKED)
# Out:
# tensorflow

# %%
import keras
from keras.models import load_model
from keras.datasets import cifar10
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, Activation, Flatten, Reshape
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
from keras.layers.advanced_activations import ELU
import os
import pickle
import numpy as np
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load Cifar10 dataset

# %%
batch_size = 50
epochs = 100
saveDir = "/opt/files/python/transfer/ae/"
if not os.path.isdir(saveDir):
    os.makedirs(saveDir)

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train_line = np.copy(x_train)
x_test_line = np.copy(x_test)
# Out:
# Downloading data from http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 169869312/170498071 [============================>.] - ETA: 0s

# %% [markdown]
# ## draw black lines to data

# %%
def drawLines(x):
    for i in range(len(x)):
        numLines = np.random.randint(20) + 1
        for l in range(numLines):
            if l % 2 == 0:
                vh = np.random.randint(2)
                start = np.random.randint(10)
                length = start + np.random.randint(4,21)
                position = np.random.randint(32)
                for j in range(3):
                    if vh == 0:
                        x[i,:,:,j][start:length, position] = 0
                    else:
                        x[i,:,:,j][position, start:length] = 0
            else:
                vh = np.random.randint(2)
                start = np.random.randint(10,25)
                length = start + np.random.randint(5,32-start)
                position = np.random.randint(32)
                for j in range(3):
                    if vh == 0:
                        x[i,:,:,j][start:length, position] = 0
                    else:
                        x[i,:,:,j][position, start:length] = 0
    return x

# %%
x_train_line = drawLines(x_train_line)
x_test_line = drawLines(x_test_line)

# %% [markdown]
# ## normalize data

# %%
# normalize data
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

x_train_line = x_train_line.astype('float32')
x_test_line = x_test_line.astype('float32')
x_train_line /= 255
x_test_line /= 255

# %%
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## show noisy images

# %%
# definition to show original image and reconstructed image
def showOrigDec(orig, noise, num=10):
    import matplotlib.pyplot as plt
    n = num
    plt.figure(figsize=(20, 4))

    for i in range(n):
        # display original
        ax = plt.subplot(2, n, i+1)
        plt.imshow(orig[i].reshape(32, 32, 3))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        
        # display original
        ax = plt.subplot(2, n, i +1 + n)
        plt.imshow(noise[i].reshape(32, 32, 3))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
showOrigDec(x_train, x_train_line)

# %%
showOrigDec(x_train[100:], x_train_line[100:])

# %%
showOrigDec(x_train[200:], x_train_line[200:])

# %% [markdown]
# ## Convolutional AutoEncoder for denoising

# %%
input_img = Input(shape=(32, 32, 3))
x = Conv2D(32, (3, 3), padding='same')(input_img)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Flatten()(x)
x = Dense(3072)(x)
x = BatchNormalization()(x)
encoded = Activation('sigmoid')(x)

# %%
x = Dense(3072)(encoded)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Reshape((32,32,3))(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Conv2D(3, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
decoded = Activation('sigmoid')(x)

# %%
model = Model(input_img, decoded)
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# ## Train AutoEncoder

# %%
# load pretrained weights
model.load_weights(saveDir + "AutoEncoder_Cifar10_deline_CAE_weights.17-0.00-0.00.hdf5")

# %%
es_cb = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')
chkpt = saveDir + 'AutoEncoder_Cifar10_delineBlack_CAE_weights.{epoch:02d}-{loss:.2f}-{val_loss:.2f}.hdf5'
cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

# %%
history = model.fit(x_train_line, x_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test_line, x_test),
                    callbacks=[es_cb, cp_cb],
                    shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0026Epoch 00000: val_loss improved from inf to 0.00182, saving model to /opt/files/python/transfer/ae/AutoEncoder_Cifar10_delineBlack_CAE_weights.00-0.00-0.00.hdf5
# 50000/50000 [==============================] - 189s - loss: 0.0026 - val_loss: 0.0018
# Epoch 2/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0022Epoch 00001: val_loss improved from 0.00182 to 0.00161, saving model to /opt/files/python/transfer/ae/AutoEncoder_Cifar10_delineBlack_CAE_weights.01-0.00-0.00.hdf5
# 50000/50000 [==============================] - 186s - loss: 0.0022 - val_loss: 0.0016
# Epoch 3/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0020Epoch 00002: val_loss improved from 0.00161 to 0.00157, saving model to /opt/files/python/transfer/ae/AutoEncoder_Cifar10_delineBlack_CAE_weights.02-0.00-0.00.hdf5
# 50000/50000 [==============================] - 186s - loss: 0.0020 - val_loss: 0.0016
# Epoch 4/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0019Epoch 00003: val_loss did not improve
# 50000/50000 [==============================] - 185s - loss: 0.0019 - val_loss: 0.0016
# Epoch 5/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0018Epoch 00004: val_loss improved from 0.00157 to 0.00148, saving model to /opt/files/python/transfer/ae/AutoEncoder_Cifar10_delineBlack_CAE_weights.04-0.00-0.00.hdf5
# 50000/50000 [==============================] - 186s - loss: 0.0018 - val_loss: 0.0015
# Epoch 6/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0018Epoch 00005: val_loss improved from 0.00148 to 0.00143, saving model to /opt/files/python/transfer/ae/AutoEncoder_Cifar10_delineBlack_CAE_weights.05-0.00-0.00.hdf5
# 50000/50000 [==============================] - 186s - loss: 0.0018 - val_loss: 0.0014
# Epoch 7/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0017Epoch 00006: val_loss did not improve
# 50000/50000 [==============================] - 185s - loss: 0.0017 - val_loss: 0.0015
# Epoch 8/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0016Epoch 00007: val_loss did not improve
# 50000/50000 [==============================] - 185s - loss: 0.0016 - val_loss: 0.0015
# Epoch 9/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0016Epoch 00008: val_loss improved from 0.00143 to 0.00139, saving model to /opt/files/python/transfer/ae/AutoEncoder_Cifar10_delineBlack_CAE_weights.08-0.00-0.00.hdf5
# 50000/50000 [==============================] - 186s - loss: 0.0016 - val_loss: 0.0014
# Epoch 10/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0015Epoch 00009: val_loss improved from 0.00139 to 0.00134, saving model to /opt/files/python/transfer/ae/AutoEncoder_Cifar10_delineBlack_CAE_weights.09-0.00-0.00.hdf5
# 50000/50000 [==============================] - 186s - loss: 0.0015 - val_loss: 0.0013
# Epoch 11/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0015Epoch 00010: val_loss did not improve
# 50000/50000 [==============================] - 185s - loss: 0.0015 - val_loss: 0.0014
# Epoch 12/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0015Epoch 00011: val_loss did not improve
# 50000/50000 [==============================] - 185s - loss: 0.0015 - val_loss: 0.0014
# Epoch 13/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0014Epoch 00012: val_loss did not improve
# 50000/50000 [==============================] - 185s - loss: 0.0014 - val_loss: 0.0015
# Epoch 14/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0014Epoch 00013: val_loss improved from 0.00134 to 0.00130, saving model to /opt/files/python/transfer/ae/AutoEncoder_Cifar10_delineBlack_CAE_weights.13-0.00-0.00.hdf5
# 50000/50000 [==============================] - 186s - loss: 0.0014 - val_loss: 0.0013
# Epoch 15/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0014Epoch 00014: val_loss did not improve
# 50000/50000 [==============================] - 185s - loss: 0.0014 - val_loss: 0.0013
# Epoch 16/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0013Epoch 00015: val_loss did not improve
# 50000/50000 [==============================] - 184s - loss: 0.0013 - val_loss: 0.0014
# Epoch 17/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0013Epoch 00016: val_loss did not improve
# 50000/50000 [==============================] - 185s - loss: 0.0013 - val_loss: 0.0013
# Epoch 18/100
# 49950/50000 [============================>.] - ETA: 0s - loss: 0.0013Epoch 00017: val_loss did not improve
# 50000/50000 [==============================] - 185s - loss: 0.0013 - val_loss: 0.0014
# Epoch 00017: early stopping

# %% [markdown]
# ## Evaluate with test dataset

# %%
score = model.evaluate(x_test_line, x_test, verbose=1)
print(score)
# Out:
#  9952/10000 [============================>.] - ETA: 0s0.00139122980386

# %% [markdown]
# ## Visualize original image, noisy image and denoised image

# %%
c10test = model.predict(x_test_line)

# %%
# definition to show original image and reconstructed image
def showOrigDec(orig, noise, denoise, num=10):
    import matplotlib.pyplot as plt
    n = num
    plt.figure(figsize=(20, 6))

    for i in range(n):
        # display original
        ax = plt.subplot(3, n, i+1)
        plt.imshow(orig[i].reshape(32, 32, 3))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # display noisy image
        ax = plt.subplot(3, n, i +1 + n)
        plt.imshow(noise[i].reshape(32, 32, 3))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        
        # display denoised image
        ax = plt.subplot(3, n, i +1 + n + n)
        plt.imshow(denoise[i].reshape(32, 32, 3))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
showOrigDec(x_test, x_test_line, c10test)

# %%
showOrigDec(x_test[100:], x_test_line[100:], c10test[100:])

# %%
showOrigDec(x_test[200:], x_test_line[200:], c10test[200:])
